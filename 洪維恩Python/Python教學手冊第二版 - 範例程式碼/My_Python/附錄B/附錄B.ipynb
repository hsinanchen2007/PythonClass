# %% [markdown]
# ### 附錄 B: Colab 的使用

# %% [markdown]
# #### B.1 啟動 Colab

# %% [markdown]
# #### B.2 鍵入程式碼與文字儲存格

# %%
1+2
# Out:
# 3

# %%
67/20
# Out:
# 3.35

# %%
print('Hello python')
# Out:
# Hello python

# %%
print('Python程式設計')
# Out:
# Python程式設計

# %%
print('Some statements')
100-36
256*100
# Out:
# Some statements
# 25600

# %%
print('Some statements')
print(100-36)
print(256*100)
# Out:
# Some statements
# 64
# 25600

# %% [markdown]
# #### B.3 儲存格的選取、複製、移動與刪除

# %% [markdown]
# #### B.4 存檔與離開 Colab

# %% [markdown]
# #### B.5 設定更舒適的操作環境

# %% [markdown]
# #### B.6 使用 Colab 的 AI 輔助學習 Python

# %%
# 判別奇偶數
a=10

# %%
# prompt: 判別10是奇數還是偶數

if a % 2 == 0:
  print("10 is even")
else:
  print("10 is odd")
# Out:
# 10 is even

# %% [markdown]
# #### B.7 在 Colab 存取雲端硬碟裡的檔案

# %%
f=open('/content/drive/MyDrive/Python教學手冊/ascii.txt','w')
f.write('Python Programming')
f.close()

# %%
f=open('/content/drive/MyDrive/Python教學手冊/ascii.txt','r')
txt=f.read()
f.close()

# %%
txt
# Out:
# 'Python Programming'

# %%
1+2
