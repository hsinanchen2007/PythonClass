# %% [markdown]
# ### 第六章 容器資料型別

# %% [markdown]
# #### 6.1 list 資料型別

# %% [markdown]
# ##### 6.1.1 list 類別提供的函數

# %%
lst=[16, 18, 13, 18, 18]

# %%
lst.count(18)
# Out:
# 3

# %%
lst.index(13)
# Out:
# 2

# %%
lst.sort(reverse = True)

# %%
lst
# Out:
# [18, 18, 18, 16, 13]

# %%
a=[5, 3, 1]; a.reverse();

# %%
print(a)
# Out:
# [1, 3, 5]

# %%
lst = [1, 2, 3]; a = lst

# %%
a[0] = 99; print(a)
# Out:
# [99, 2, 3]

# %%
lst
# Out:
# [99, 2, 3]

# %%
lst  =[1, 2, 3]; b = lst.copy()

# %%
b[0] = 99; print(b)
# Out:
# [99, 2, 3]

# %%
lst
# Out:
# [1, 2, 3]

# %% [markdown]
# ##### 6.1.2 巢狀串列

# %%
lst = [[1,3,7], [4,8], [9,3,0]]

# %%
lst[1]
# Out:
# [4, 8]

# %%
lst[1][0]
# Out:
# 4

# %%
lst[2]
# Out:
# [9, 3, 0]

# %%
lst[2][1:]
# Out:
# [3, 0]

# %%
grade = [[67, 80, 87, 69],
         [71, 80, 65, 53],
         [77, 58, 60, 49]]

# %%
len(grade)
# Out:
# 3

# %%
len(grade[0])
# Out:
# 4

# %%
grade[0]
# Out:
# [67, 80, 87, 69]

# %%
[c[0] for c in grade]
# Out:
# [67, 71, 77]

# %%
# ch6_1.py, 包含學生姓名及多科成績的巢狀串列
students = [
    ['Alice', [85, 90, 78]],  
    ['Bob', [88, 76, 92]],  
    ['Charlie', [90, 85, 89]]  
]

# 計算每位學生的平均成績
for student in students:
    name = student[0]
    scores = student[1]
    avg_score = sum(scores) / len(scores)
    print(f'{name} 的平均成績為 {avg_score:.2f}')
# Out:
# Alice 的平均成績為 84.33
# Bob 的平均成績為 85.33
# Charlie 的平均成績為 88.00

# %% [markdown]
# ##### 6.1.3 串列的設定、淺拷貝和深拷貝

# %%
# ch6_2.py, 設定運算、淺拷貝和深拷貝的比較
import copy  				# 載入 copy 模組
lst = [[1, 2], 34]		# 建立一個原始串列

# 設定運算（指向同一個 list）
a = lst   				# a 和 lst 指向相同的記憶體位址
a[0][0] = 99  			# 修改 a[0][0]
print('設定運算:', lst)	# [[99, 2], 34]，lst 也被修改

# 淺拷貝：copy()
lst = [[1, 2], 34]		# 重設 lst
b = lst.copy()			# 建立淺拷貝
b[0][0] = 99 				# 修改 b[0][0]
print('淺拷貝:', lst)		# [[99, 2], 34]，lst 仍然被影響

# 深拷貝：copy.deepcopy()
lst = [[1, 2], 34]  		# 重設 lst
c = copy.deepcopy(lst)	# 建立深拷貝
c[0][0] = 99  # 修改 c[0][0]
print('深拷貝:', lst)  	# [[1, 2], 34]，lst 不受影響
# Out:
# 設定運算: [[99, 2], 34]
# 淺拷貝: [[99, 2], 34]
# 深拷貝: [[1, 2], 34]

# %% [markdown]
# #### 6.2 tuple 資料型別

# %% [markdown]
# ##### 6.2.1 元組的建立與操作

# %%
5, 3, 'Jerry'
# Out:
# (5, 3, 'Jerry')

# %%
(5, 3, 'Jerry')
# Out:
# (5, 3, 'Jerry')

# %%
type((5, 3, 'Jerry'))
# Out:
# tuple

# %%
tuple(range(5, 10))
# Out:
# (5, 6, 7, 8, 9)

# %%
tuple('python')
# Out:
# ('p', 'y', 't', 'h', 'o', 'n')

# %%
(3)
# Out:
# 3

# %%
(3,)
# Out:
# (3,)

# %%
tpl=(16, 43, 27)

# %%
tpl.index(27)
# Out:
# 2

# %%
tpl.count(16)
# Out:
# 1

# %%
tpl[1:]
# Out:
# (43, 27)

# %%
max(tpl), min(tpl), len(tpl)
# Out:
# (43, 16, 3)

# %%
2*tpl
# Out:
# (16, 43, 27, 16, 43, 27)

# %%
tpl+(99,)
# Out:
# (16, 43, 27, 99)

# %% [markdown]
# ##### 6.2.2 再談可變與不可變物件

# %%
# ch6_3.py, 比較串列與元組的元素位址變化
lst = [10, 20, 30]   	# 串列
tpl = (10, 20, 30)   	# 元組

print('修改前:')    	# 印出元素的 id（記憶體位址）
print('id(lst[0]):', id(lst[0]))  
print('id(tpl[0]):', id(tpl[0]))  

lst[0] = 99  			# 串列允許修改
# tpl[0] = 99  		# 這行會出錯，因為元組不可變

print('修改 lst[0] 後:')
print('id(lst[0]):',id(lst[0]))  # id改變，表示lst[0]指向新物件
print('lst:', lst)
# Out:
# 修改前:
# id(lst[0]): 140723774948552
# id(tpl[0]): 140723774948552
# 修改 lst[0] 後:
# id(lst[0]): 140723774951400
# lst: [99, 20, 30]

# %%
# ch6_4.py, 修改元組中的可變物件
tpl = (4, 'cat', [1, 2])  			# 建立元組

print('修改前:')
print('id(tpl[0]):', id(tpl[0]))	# 整數
print('id(tpl[1]):', id(tpl[1]))	# 字串
print('id(tpl[2]):', id(tpl[2]))	# list

tpl[2].append(3)		# 在 list 裡面新增元素

print('修改後:')
print('id(tpl[2]):', id(tpl[2]))  # list 的位址沒變，但內容變了
print('tpl:', tpl)  	# 印出修改後的 tpl
# Out:
# 修改前:
# id(tpl[0]): 140723774948360
# id(tpl[1]): 2034555642016
# id(tpl[2]): 2034649939648
# 修改後:
# id(tpl[2]): 2034649939648
# tpl: (4, 'cat', [1, 2, 3])

# %% [markdown]
# #### 6.3 set 資料型別

# %% [markdown]
# ##### 6.3.1 集合的建立與基本運算

# %%
{3, 6, 4, 4}
# Out:
# {3, 4, 6}

# %%
set([3, 6, 4, 4])
# Out:
# {3, 4, 6}

# %%
{'Kitten'}
# Out:
# {'Kitten'}

# %%
set('Kitten')
# Out:
# {'K', 'e', 'i', 'n', 't'}

# %%
set()
# Out:
# set()

# %%
{}
# Out:
# {}

# %%
hash((12, 15))
# Out:
# 1599942983381215927

# %%
set((12, [15]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 set((12, [15]))
#
# TypeError: unhashable type: 'list'

# %%
{{1, 2, 3}}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 {{1, 2, 3}}
#
# TypeError: unhashable type: 'set'

# %%
len({4, 3, 4, 5, 5})
# Out:
# 3

# %%
max({4, 3, 4, 5, 5})
# Out:
# 5

# %%
'p' in {'p','i','g','g','y'}
# Out:
# True

# %%
{5, 6, 7, 8}[0]
# Out:
# <>:1: SyntaxWarning: 'set' object is not subscriptable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'set' object is not subscriptable; perhaps you missed a comma?
# C:\Users\Gato919\AppData\Local\Temp\ipykernel_15264\3513207146.py:1: SyntaxWarning: 'set' object is not subscriptable; perhaps you missed a comma?
#   {5, 6, 7, 8}[0]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 {5, 6, 7, 8}[0]
#
# TypeError: 'set' object is not subscriptable

# %%
{1, 2, 3, 4} > {1, 2}
# Out:
# True

# %%
{1, 2, 3}=={3, 1, 2, 2, 2, 1}
# Out:
# True

# %%
set('sun') <= set('sunny')
# Out:
# True

# %%
# ch6_5.py, 用 hash() 檢查是否出現過
seen = set()				# 空集合

data = ['apple', 'banana', 'apple', 'orange', 'banana']

for item in data:
    h = hash(item)		# 計算item的雜湊
    if h in seen:			# 如果item的雜湊已經存在集合裡
        print(f'重複項目：{item}')
    else:
        seen.add(h)		# 將雜湊加到集合裡
# Out:
# 重複項目：apple
# 重複項目：banana

# %% [markdown]
# ##### 6.3.2 set 類別提供的函數

# %%
s = {1, 2, 3, 4}

# %%
s.add(12); print(s)
# Out:
# {1, 2, 3, 4, 12}

# %%
s.remove(12); print(s)
# Out:
# {1, 2, 3, 4}

# %%
s.discard(3); print(s)
# Out:
# {1, 2, 4}

# %%
e=s.pop(); print(f'{s}, e={e}')
# Out:
# {2, 4}, e=1

# %%
s.clear(); print(s)
# Out:
# set()

# %%
{1, 2}.issubset({1, 2, 3})
# Out:
# True

# %%
{1, 2, 3}.issuperset({1, 2, 3})
# Out:
# True

# %%
{3, 4}.isdisjoint({1, 2, 3})
# Out:
# False

# %%
a = {1, 2, 4}; b = {1, 2, 3}

# %%
a.intersection(b)
# Out:
# {1, 2}

# %%
a & b
# Out:
# {1, 2}

# %%
a.union(b)
# Out:
# {1, 2, 3, 4}

# %%
a.difference(b)
# Out:
# {4}

# %%
a.symmetric_difference(b)
# Out:
# {3, 4}

# %%
# ch6_6.py, 判別兩句話的相似度
text1 = 'The quick brown fox jumps over the lazy dog'
text2 = 'A quick brown fox jumps above a lazy dog'

stopwords = {'the', 'a', 'over', 'above'}   # 停用詞集合
s1 = set(text1.split())	# 將句子分成單字，再轉集合（含停用詞）
s2 = set(text2.split())

s1c = s1 - stopwords		# 去除停用詞， - 為差集運算
s2c = s2 - stopwords		# 去除停用詞

# 計算 Jaccard 相似度
sim_raw = len(s1 & s2) / len(s1 | s2)		 # & 為交集，| 為聯集
sim_clean = len(s1c & s2c) / len(s1c | s2c)

print(f'原始相似度（含停用詞）：{sim_raw:.2f}')
print(f'去除停用詞後相似度：{sim_clean:.2f}')
# Out:
# 原始相似度（含停用詞）：0.50
# 去除停用詞後相似度：0.75

# %% [markdown]
# #### 6.4 dict 資料型別

# %% [markdown]
# ##### 6.4.1 字典的建立與基本運算

# %%
{'Tom':12, 'Jerry':7}
# Out:
# {'Tom': 12, 'Jerry': 7}

# %%
dict(Tom=12, Jerry=7)
# Out:
# {'Tom': 12, 'Jerry': 7}

# %%
dict([('Tom',12), ('Jerry',7)])
# Out:
# {'Tom': 12, 'Jerry': 7}

# %%
{(1,3):'odd', (2,4):'even'}
# Out:
# {(1, 3): 'odd', (2, 4): 'even'}

# %%
dict()
# Out:
# {}

# %%
d1={'tea':65}

# %%
d1['coffee'] = 40; print(d1)
# Out:
# {'tea': 65, 'coffee': 40}

# %%
d1['tea']
# Out:
# 65

# %%
len(d1)
# Out:
# 2

# %%
d1['coffee'] = 46; print(d1)
# Out:
# {'tea': 65, 'coffee': 46}

# %%
del d1['tea']; print(d1)
# Out:
# {'coffee': 46}

# %%
d1={'apple': 20, 'orange': 15}

# %%
'orange' in d1
# Out:
# True

# %%
'candy' not in d1
# Out:
# True

# %%
{'a':3, 'b':5} == {'b':5, 'a':3}
# Out:
# True

# %% [markdown]
# ##### 6.4.2 dict 類別提供的函數

# %%
d = {0:'red', 1:'green'}

# %%
d.get(0)
# Out:
# 'red'

# %%
d.get(2, 'white')
# Out:
# 'white'

# %%
d.keys()
# Out:
# dict_keys([0, 1])

# %%
list(d.values())
# Out:
# ['red', 'green']

# %%
tuple(d.items())
# Out:
# ((0, 'red'), (1, 'green'))

# %%
dict.fromkeys([0, 1])
# Out:
# {0: None, 1: None}

# %%
dict.fromkeys([0, 1], 'red')
# Out:
# {0: 'red', 1: 'red'}

# %%
d={0:'red'}

# %%
d.update({1:'green'}); print(d)
# Out:
# {0: 'red', 1: 'green'}

# %%
a=d.pop(1); print(a, d)
# Out:
# green {0: 'red'}

# %%
d.popitem()
# Out:
# (0, 'red')

# %%
d
# Out:
# {}

# %%
d1 = {10: 'a', 20: 'b'}

# %%
d2 = {5: 'c'}

# %%
d1.update(d2); print(d1)
# Out:
# {10: 'a', 20: 'b', 5: 'c'}

# %%
last_item = d1.popitem()

# %%
print(last_item)
# Out:
# (5, 'c')

# %%
print(d1)
# Out:
# {10: 'a', 20: 'b'}

# %%
# ch6_7.py, 計算單字出現的次數
count = {}  # 初始化一個空字典
words = ['apple', 'banana', 'apple', 'orange', 'banana', 'apple']

# 使用 setdefault 函數來計算每個單字出現的次數
for word in words:
    count.setdefault(word, 0)
    count[word] += 1

print(count)
# Out:
# {'apple': 3, 'banana': 2, 'orange': 1}

# %%
# ch6_8.py, 字典的淺拷貝
# 預設贈品清單
default = {
    'user': 'customer',
    'gifts': ['A', 'B']
}

a_copy = default.copy()   		# 顧客a的贈品清單（淺拷貝）
a_copy['user'] = 'Isabelle'  	# 修改顧客a的名字
a_copy['gifts'].append('C')  	# 顧客a新增一個贈品

print('預設清單: ', default)  	# 出現問題：預設清單被修改
print('顧客a清單:', a_copy)
# Out:
# 預設清單:  {'user': 'customer', 'gifts': ['A', 'B', 'C']}
# 顧客a清單: {'user': 'Isabelle', 'gifts': ['A', 'B', 'C']}

# %%
# ch6_9.py, 字典的深拷貝
import copy
default = {     # 預設贈品清單
    'user': 'customer',
    'gifts': ['A', 'B']
}

a_copy = copy.deepcopy(default)	# 顧客a的贈品清單（深拷貝）
a_copy['user'] = 'Isabelle'  		# 修改顧客a的名字
a_copy['gifts'].append('C')  		# 顧客a新增一個贈品

print('預設清單: ', default)  		# 這行不會出現問題了
print('顧客a清單:', a_copy)
# Out:
# 預設清單:  {'user': 'customer', 'gifts': ['A', 'B']}
# 顧客a清單: {'user': 'Isabelle', 'gifts': ['A', 'B', 'C']}
