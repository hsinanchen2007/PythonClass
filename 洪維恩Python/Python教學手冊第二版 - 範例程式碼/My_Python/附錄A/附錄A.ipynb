# %% [markdown]
# ### 附錄A: 使用 Jupyter Notebook

# %% [markdown]
# #### A.1 安裝 Jupyter 擴充功能

# %% [markdown]
# #### A.2 鍵入程式碼

# %%
1+2
# Out:
# 3

# %%
67/20
# Out:
# 3.35

# %%
print('Hello python')
# Out:
# Hello python

# %%
print('Python 程式設計')
# Out:
# Python 程式設計

# %%
print('Some statements')
100-36
256*100
# Out:
# Some statements
# 25600

# %%
print('Some statements')
print(100-36)
print(256*100)
# Out:
# Some statements
# 64
# 25600

# %% [markdown]
# #### A.3 儲存格的選取、複製、移動與刪除

# %% [markdown]
# #### A.4 存檔與離開 Jupyter Notebook

# %%
printf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 printf
#
# NameError: name 'printf' is not defined

# %% [markdown]
# #### A.5 Markdown 語法

# %% [markdown]
# # 第一個Python程式
# ## 練習標題輸入
# 這是其它文字

# %% [markdown]
# # 我是一級標題
# ## 我是二級標題
# ### 我是三級標題
# #### 我是四級標題
# ##### 我是五級標題
# ###### 我是六級標題

# %% [markdown]
# **這是粗體文字**        __這是粗體文字__
#
# *這是斜體文字*          _這是斜體文字_
#
# ***這是粗斜體文字***    ___這是粗斜體文字___

# %% [markdown]
# - 我是項目1
# - 我是項目2
#   - 我是子項目a
#   * 我是子項目b
#   + 我是子項目c
#
# 1. 我是項目1
# 2. 我是項目2
#     1. 我是子項目1
#     2. 我是子項目2

# %% [markdown]
# ![Python logo](https://www.python.org/static/img/python-logo.png)

# %% [markdown]
# | 姓名 | 年齡 | 城市 |
# |:-------|:----:|--------:|
# | Alice  | 25   | New York |
# | Bob    | 30   | San Francisco |

# %% [markdown]
# 分隔線的語法
#
# ---
# 這是一行文字<br>
# 我要換行

# %% [markdown]
# 與文字同一行: $E=mc^2$
#
# 單獨一行:
# $$
# \int_0^\infty e^{-x^2} dx = \frac{\sqrt{\pi}}{2}
# $$

# %% [markdown]
# #### A.6 於 Jupyter Notebook 裡製作目錄
