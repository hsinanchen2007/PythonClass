# %% [markdown]
# ### 第四章 流程控制：選擇性敘述與迴圈

# %% [markdown]
# #### 4.1 選擇性敘述

# %% [markdown]
# ##### 4.1.1 if敘述

# %%
# ch4_1.py, 判別是否可以考駕照 
age = int(input('請輸入您的年齡：'))

if age >= 18:  
    print('您已滿 18 歲，可以考駕照')   # 這行要縮排（一般4個空格）
print('程式結束')
# Out:
# 您已滿 18 歲，可以考駕照
# 程式結束

# %% [markdown]
# ##### 4.1.2 if-else敘述

# %%
# ch4_2.py, 檢查手機號碼格式
num = input('請輸入手機號碼（格式：09xx-xxx-xxx）：')

if num[:2] == '09' and num[4] == '-' and num[8] == '-':
    print('格式正確')
    print(f'您輸入的號碼為 {num:s}') 
else:
    print('格式錯誤')
# Out:
# 格式錯誤

# %% [markdown]
# ##### 4.1.3 單行的if-else敘述

# %%
# ch4_3.py, 傳統與單行if-else 敘述的比較（判別成績是否及格）
score = int(input('請輸入分數：'))

if score >= 60: 			# 傳統的 if-else
    result1 = '及格'
else:
    result1 = '不及格'

result2 = '及格' if score >= 60 else '不及格'  # 單行的 if-else

print(f'傳統 if-else 的結果：{result1}')
print(f'單行 if-else 的結果：{result2}')
# Out:
# 傳統 if-else 的結果：及格
# 單行 if-else 的結果：及格

# %% [markdown]
# ##### 4.1.4 if-elif-else敘述

# %%
# ch4_4.py, 判別一個數是正數、0或是負數
num = int(input('請輸入一個整數：'))

if num > 0:
    print('您輸入的是正數')
elif num < 0:
    print('您輸入的是負數')
else:
    print('您輸入的是零')

# %%
# ch4_5.py, 成績等級評定
score = int(input('請輸入分數: '))  # 輸入分數，並轉換為整數

if score >= 90:		# 判斷分數是否大於等於90
    grade = 'A'		
elif score >= 80: 	# 如果小於90，且大於等於80
    grade = 'B' 
elif score >= 70: 	# 如果小於80，且大於等於70
    grade = 'C'  
elif score >= 60: 	# 如果小於70，且大於等於60
    grade = 'D' 
else:  				# 若以上條件皆不成立（小於60）
    grade = 'F'  		
print(f'你的等級是: {grade}')  #輸出成績等級
# Out:
# 你的等級是: B

# %% [markdown]
# ##### 4.1.5 巢狀的選擇性敘述

# %%
# ch4_6.py, 根據氣溫提供適當的穿衣或防護建議
temp = int(input('請輸入氣溫: \xB0C): ')) 
humidity = int(input('請輸入濕度(%): '))

if temp < 15:  # 若氣溫低於15度
    if humidity > 80:  # 若濕度高於80%
        print('很冷且潮濕，穿厚外套和防水衣')
    else:
        print('很冷，穿厚外套')
elif temp <= 30:  # 若氣溫介於15到30度
    if humidity > 80:  # 若濕度高於80%
        print('舒適但潮濕，穿輕便防水衣')
    else:
        print('舒適，輕便穿搭')
else:  # 若氣溫高於30度
    if humidity > 80:  # 若濕度高於80%
        print('炎熱且潮濕，多喝水並穿輕便防水衣')
    else:
        print('炎熱，多喝水並防曬')
# Out:
# 舒適，輕便穿搭

# %% [markdown]
# #### 4.2 for迴圈

# %% [markdown]
# ##### 4.2.1 for迴圈的基本語法

# %%
# ch4_7.py, for迴圈走訪字串
for i in 'Cat':	# i為迴圈變數
    print(i)    	# 印出字元i
# Out:
# C
# a
# t

# %%
# ch4_8.py, for 迴圈走訪串列
fruits = ['apple', 'banana', 'cherry']
for fruit in fruits:
    print(fruit.title())
# Out:
# Apple
# Banana
# Cherry

# %%
# ch4_9.py, for 迴圈走訪串列並加總數字
numbers = [4, 6, 3]
total = 0			# 設定初值為0
for num in numbers:	# 走訪numbers
    total += num       # 累加total

print('總和為:', total)
# Out:
# 總和為: 13

# %%
# ch4_10.py, 找出串列中的最大值
numbers = [3, 7, 9, 2]	# 定義一個串列
max_value = numbers[0]	# 假設索引0的數字為最大值

for num in numbers:  		# 走訪串列中的每個數字
    if num > max_value:  	# 如果發現更大的數字
        max_value = num   	# 更新最大值變數

print('最大值為:', max_value)  # 印出最大值
# Out:
# 最大值為: 9

# %% [markdown]
# ##### 4.2.2 關於pythontutor.com網站

# %% [markdown]
# ##### 4.2.3 走訪range() 函數生成的物件

# %%
# ch4_11.py, 走訪range()並計算偶數的平均
total = 0  	# 用來存儲偶數的總和
count = 0  	# 存放偶數的個數

for num in range(1, 11):	# 走訪 1 到 10（不含 11）
    if num % 2 == 0:		# 判斷是否為偶數
        total += num		# 加總偶數
        count += 1			# 計算偶數個數

average = total / count   # 計算平均值
print('偶數的平均值:', average)
# Out:
# 偶數的平均值: 6.0

# %% [markdown]
# ##### 4.2.4 巢狀的for迴圈

# %%
# ch4_12.py, 九九乘法表
for r in range(1, 6):  # 外層迴圈，控制乘數
    for c in range(1, 9): # 內層迴圈，控制被乘數
        print(f'{r}*{c}={r * c:2d}', end=' ')
    print()  # 換行，開始印下一列
# Out:
# 1*1= 1 1*2= 2 1*3= 3 1*4= 4 1*5= 5 1*6= 6 1*7= 7 1*8= 8
# 2*1= 2 2*2= 4 2*3= 6 2*4= 8 2*5=10 2*6=12 2*7=14 2*8=16
# 3*1= 3 3*2= 6 3*3= 9 3*4=12 3*5=15 3*6=18 3*7=21 3*8=24
# 4*1= 4 4*2= 8 4*3=12 4*4=16 4*5=20 4*6=24 4*7=28 4*8=32
# 5*1= 5 5*2=10 5*3=15 5*4=20 5*5=25 5*6=30 5*7=35 5*8=40

# %%
# ch4_13.py, 產生數字遞減的三角形圖案
for r in range(0,5):  # 外層迴圈，控制列數，r從0遞增到4
    for c in range(1,6-r):		# 內層迴圈，控制每列要印出幾個數字
        print(c, end="")  		# 印出數字
    print()  # 換列，準備印下一列
# Out:
# 12345
# 1234
# 123
# 12
# 1

# %% [markdown]
# #### 4.3 while迴圈

# %%
# ch4_14.py, 利用while迴圈來計算1加到5
total=0
n=1
while n<=5:
    total=total+n
    n=n+1
print(total)
# Out:
# 15

# %%
# ch4_15.py, 使用 while 猜測數字
import random
target = random.randint(1, 10)   # 隨機產生1到10的數字
guess = 0  # 用來存放使用者的猜測值

while guess != target:  	# 當猜錯時，持續執行
    guess = int(input('猜一個1到10之間的數字: '))
    if guess < target:
        print('太小了！請再試一次')
    elif guess > target:
        print('太大了！請再試一次')
print('恭喜你，猜對了！')
# Out:
# 太大了！請再試一次
# 太大了！請再試一次
# 太大了！請再試一次
# 太大了！請再試一次
# 太大了！請再試一次
# 太大了！請再試一次
# 太大了！請再試一次
# 恭喜你，猜對了！

# %%
# ch4_16.py, 使用while列印數字遞增的三角形
row = 1  # 控制列數

while row <= 5:  		# 外層迴圈，決定要印出幾列
    col = 1  				
    while col <= row:  	# 內層迴圈，決定當前要印幾個數字
        print(col, end="")     # 印出數字但不換列
        col += 1  		# 讓行數遞增
    print()	# 換列
    row += 1	# 讓列數遞增
# Out:
# 1
# 12
# 123
# 1234
# 12345

# %% [markdown]
# #### 4.4 break、continue和pass敘述

# %% [markdown]
# ##### 4.4.1 break敘述

# %%
# ch4_17.py, 搜尋字元
text = 'Hello, world!'
target = ','		# 欲搜尋的字元

for ch in text:
    if ch == target:
        print('找到字元:', target)
        break     # 找到字元，終止迴圈
    print('目前字元:', ch)
# Out:
# 目前字元: H
# 目前字元: e
# 目前字元: l
# 目前字元: l
# 目前字元: o
# 找到字元: ,

# %%
# ch4_18.py, 限制密碼的輸入次數
password = 'python123'  # 正確密碼
attempts = 0  # 記錄輸入次數

while attempts < 3:  # 最多允許3次輸入
    pwd = input('請輸入密碼: ')  # 使用者輸入密碼
    if pwd == password:
        print('密碼正確，登入成功！')
        break  # 結束迴圈
    else:
        print('密碼錯誤！')
        attempts += 1  # 增加錯誤次數

if attempts == 3:
    print('輸入錯誤3次，系統鎖定！')
# Out:
# 密碼錯誤！
# 密碼正確，登入成功！

# %%
# ch4_19.py, 利用break跳離無窮迴圈
while True:  
    cmd = input("請輸入指令 (輸入 'exit' 結束): ")  
    if cmd == 'exit':  
        print('程式已結束')  
        break        # 跳離while迴圈
    print(f'你輸入的是: {cmd}')
# Out:
# 你輸入的是: hello
# 你輸入的是: 123
# 程式已結束

# %% [markdown]
# ##### 4.4.2 continue敘述

# %%
# ch4_20.py, 使用continue跳過負數進行累加
numbers = [10, -5, 3, -1, 7, -6, 2]   # 包含正數和負數的串列
total_sum = 0   		# 初始化總和變數

for num in numbers:	# 走訪串列中的每個數字
    if num < 0:
        continue		# 如果數字是負數，跳過這次迭代
    total_sum += num	# 將正數加到總和中

print('正數的總和是:', total_sum)
# Out:
# 正數的總和是: 22

# %% [markdown]
# ##### 4.4.3 pass敘述

# %%
# ch4_21.py, 檢查數字串列中的奇偶數，並印出奇數
numbers = [4, 7, 10, 3, 8, 5]

for num in numbers:
    if num % 2 == 0:
        pass  # 之後可能會加入處理偶數的程式
    else:
        print(f'{num} 是奇數')
# Out:
# 7 是奇數
# 3 是奇數
# 5 是奇數

# %% [markdown]
# #### 4.5 帶有else的迴圈

# %%
# ch4_22.py, 檢查輸入的串列是否有負數（沒有else的寫法）
numbers=eval(input('請輸入一個串列: '))
found=False  			# 用found來記錄是否有負數被找到
for num in numbers:
    if num<0: 
        print('找到負數')
        found=True		# 找到負數
        break			# 跳離for迴圈
if not found:			# 如果沒有找到負數
    print('都是正數')
# Out:
# 都是正數

# %%
# ch4_23.py, 檢查輸入的串列是否有負數（for-else的寫法）
lst=eval(input('請輸入一個串列: '))
for n in lst:
    if n<0:
        print('找到負數')
        break
else:
    print('都是正數')
# Out:
# 找到負數

# %%
# ch4_24.py, 檢查輸入的串列是否有負數（for-else的寫法）
num = int(input('請輸入一個大於1的數: '))
divisor = 2

while divisor < num:
    if num % divisor == 0:   # 可以被divisor整除
        print(f'{num}不是質數，因為可以被{divisor}整除。')
        break
    divisor += 1
else:
    print(f'{num}是質數！')
# Out:
# 11是質數！

# %% [markdown]
# #### 4.6 串列推導式

# %% [markdown]
# ##### 4.6.1 簡單的串列推導式

# %%
[i**2 for i in [3,5,-1,4,9]]
# Out:
# [9, 25, 1, 16, 81]

# %%
[i for i in [3,5,-1,4,9] if i>0]
# Out:
# [3, 5, 4, 9]

# %%
[i if i>0 else 0 for i in [6,-1,3]]
# Out:
# [6, 0, 3]

# %%
[c for c in 'apple' if c in 'aeiou']
# Out:
# ['a', 'e']

# %%
[i**2 if i%2==0 else i for i in [3,6,-6,4,9] if i>0]
# Out:
# [3, 36, 16, 9]

# %%
# ch4_25.py, 找出輸入數字的所有因數
n = int(input('請輸入一個數字: '))
# 使用 for 迴圈找出因數
factors_for = []
for i in range(1, n+1):
    if n % i == 0:   # 找到因數
        factors_for.append(i)
print(f'{n} 的因數有 (for 迴圈):', factors_for)

# 使用串列推導式找出因數
factors_list_comp = [i for i in range(1, n+1) if n % i == 0]
print(f'{n} 的因數有 (串列推導式):', factors_list_comp)
# Out:
# 12 的因數有 (for 迴圈): [1, 2, 3, 4, 6, 12]
# 12 的因數有 (串列推導式): [1, 2, 3, 4, 6, 12]

# %% [markdown]
# ##### 4.6.2 巢狀的串列推導式

# %%
# ch4_26.py，字母與數字的組合
chars = ['a', 'b']
numbers = ['1', '2', '3']
combinations = [c + n for c in chars  for n in numbers] 
print(combinations)
# Out:
# ['a1', 'a2', 'a3', 'b1', 'b2', 'b3']

# %%
# ch4_27.py, 將兩個字串的字母轉成大寫
words = ['hi', ' hello']
chars = [c.upper() for word in words  for c in word]
print(''.join(chars))
# Out:
# HI HELLO
