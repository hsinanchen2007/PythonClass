# %% [markdown]
# ### 第三章 數值、字串與串列的處理

# %% [markdown]
# #### 3.1 數值運算

# %% [markdown]
# ##### 3.1.1 內建數學函數

# %%
abs(-4.8)
# Out:
# 4.8

# %%
round(0.250,1)
# Out:
# 0.2

# %%
pow(2,100)
# Out:
# 1267650600228229401496703205376

# %%
min(8, -32, 62.9, 20)
# Out:
# -32

# %% [markdown]
# ##### 3.1.2 math 模組裡的基本數學函數

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.inf*0
# Out:
# nan

# %%
math.factorial(5)
# Out:
# 120

# %%
math.ceil(9.1)
# Out:
# 10

# %%
math.fmod(23,4)
# Out:
# 3.0

# %%
math.gcd(36,64)
# Out:
# 4

# %%
math.isfinite(90)
# Out:
# True

# %%
# ch3_1.py, math 模組的使用範例
import math

# 計算圓的面積
radius = float(input('輸入圓的半徑：'))
area = math.pi * (radius ** 2)
print(f'圓的面積是：{area:.2f}')

# 計算平方根
num = abs(float(input('輸入一個數：')))      # 取絕對值，避免錯誤
sqrt_value = math.sqrt(num)
print(f'{num} 的平方根是：{sqrt_value:.2f}')

# 四捨五入的計算
float_num = float(input('輸入一個浮點數：'))
rounded_num = round(float_num)
print(f'{float_num} 捨入到整數的結果是：{rounded_num}')
# Out:
# 圓的面積是：113.10
# 16.0 的平方根是：4.00
# 5.0 捨入到整數的結果是：5

# %% [markdown]
# ##### 3.1.3 math 模組裡的指數、對數與三角函數

# %%
import math

# %%
math.exp(1)
# Out:
# 2.718281828459045

# %%
math.log10(1000)
# Out:
# 3.0

# %%
math.pow(3,50)
# Out:
# 7.178979876918526e+23

# %%
math.sqrt(3)
# Out:
# 1.7320508075688772

# %%
math.degrees(math.atan(1))
# Out:
# 45.0

# %%
math.radians(180)
# Out:
# 3.141592653589793

# %% [markdown]
# #### 3.2 random 模組裡的函數

# %%
import random

# %%
random.random()
# Out:
# 0.7634582648737311

# %%
random.randint(0, 10)
# Out:
# 8

# %%
random.randrange(-3, 3, 2)
# Out:
# -3

# %%
random.choices('Python', k=4)
# Out:
# ['o', 'n', 'o', 'n']

# %%
random.sample('Hello Python', 3)
# Out:
# ['n', 'e', 'H']

# %%
lst=[9, 2, 3, 1, 0]

# %%
random.shuffle(lst)

# %%
lst
# Out:
# [3, 2, 1, 0, 9]

# %%
random.seed(999)

# %%
print(random.random())
print(random.random())
print(random.random())
# Out:
# 0.7813468849570298
# 0.0800656147037001
# 0.8724924964292878

# %%
random.seed(999)

# %%
print(random.random())
print(random.random())
print(random.random())
# Out:
# 0.7813468849570298
# 0.0800656147037001
# 0.8724924964292878

# %%
# ch3_2.py, random 模組模擬抽獎活動
import random
# 參加者名單，由學生名字組成的串列
students= ['Alice', 'Bob', 'Tom', 'David', 'Eve']  

# 隨機抽取兩位得獎者（不重複）
winners = random.sample(students, 2)

print('得獎者是：', winners)     # 輸出得獎者名單
# Out:
# 得獎者是： ['Eve', 'David']

# %% [markdown]
# #### 3.3 字串的處理函數

# %% [markdown]
# ##### 3.3.1 認識 Python 字元的編碼

# %%
print(ord('a'),ord('好'))
# Out:
# 97 22909

# %%
print(hex(ord('好')))
# Out:
# 0x597d

# %% [markdown]
# ##### 3.3.2 字元的 8 進位與 16 進位表示法

# %%
print('\101')
# Out:
# A

# %%
print('\x41\u0041')
# Out:
# AA

# %%
print('Character: \u597d')
# Out:
# Character: 好

# %%
# ch3_3.py, 字元的8進位與16進位表示法 
# 換行符號 (16進位的ASCII 碼為 0A)
print('這是一行文字\x0A這是下一行文字')

# 表示版權符號
copyright = '\u00A9'	# Unicode 字元的16進位表示法
print(f'版權符號：{copyright}')

# 表示黑桃符號
spade = '\u2660'	# Unicode 字元的16進位表示法
print(f'黑桃符號：{spade}')
# Out:
# 這是一行文字
# 這是下一行文字
# 版權符號：©
# 黑桃符號：♠

# %% [markdown]
# ##### 3.3.3 取得字元或字串的相關訊息

# %%
ord('A'),ord('a'),ord('@')
# Out:
# (65, 97, 64)

# %%
max('AaQ')
# Out:
# 'a'

# %%
chr(65)
# Out:
# 'A'

# %%
len('Python程式設計')
# Out:
# 10

# %%
str(3.14)
# Out:
# '3.14'

# %% [markdown]
# ##### 3.3.4 處理字串的運算子

# %%
'520' * 3
# Out:
# '520520520'

# %%
'Have '+'a '+'nice '+'day'
# Out:
# 'Have a nice day'

# %%
'W' < 'e'
# Out:
# True

# %%
'holiday' == 'birthday'
# Out:
# False

# %%
'apple' < 'applepie'
# Out:
# True

# %%
'mat' in 'formation'
# Out:
# True

# %%
'tion' not in 'formation'
# Out:
# False

# %% [markdown]
# ##### 3.3.5 字元的提取

# %%
s1 = 'Python程式設計'

# %%
s1[-4:]
# Out:
# '程式設計'

# %%
s1[6:8]
# Out:
# '程式'

# %%
# ch3_4.py, 字串運算子範例 
s1 = input('請輸入第一個字串：')
s2 = input('請輸入第二個字串：')

print(f'字串連接：{s1 + s2}')  # 字串連接
print(f'重複字串：{s1 * 3}')   # 字串重複三次
print(f'字串比較：{s1} > {s2} 為 {s1 > s2}')  # 比較字串大小
print(f"'{s1}' 的前三個字元是：{s1[:3]}")  # 提取 s1 的前三個字元
# Out:
# 字串連接：HelloWorld
# 重複字串：HelloHelloHello
# 字串比較：Hello > World 為 False
# 'Hello' 的前三個字元是：Hel

# %% [markdown]
# #### 3.4 字串類別提供的函數

# %%
type(5)
# Out:
# int

# %%
type('nice')
# Out:
# str

# %%
'nice'.capitalize()
# Out:
# 'Nice'

# %%
str.capitalize('nice')
# Out:
# 'Nice'

# %% [markdown]
# ##### 3.4.1 字串大小寫的轉換函數

# %%
s = 'machine LEARNing'

# %%
s.upper()
# Out:
# 'MACHINE LEARNING'

# %%
s
# Out:
# 'machine LEARNing'

# %%
str.upper(s)
# Out:
# 'MACHINE LEARNING'

# %%
s.swapcase()
# Out:
# 'MACHINE learnING'

# %%
s.title()
# Out:
# 'Machine Learning'

# %%
s.capitalize()
# Out:
# 'Machine learning'

# %%
str='holiday'

# %%
str.upper('aaa')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 str.upper('aaa')
#
# TypeError: str.upper() takes no arguments (1 given)

# %%
del str

# %%
str.upper('aaa')
# Out:
# 'AAA'

# %% [markdown]
# ##### 3.4.2 字串檢測函數

# %%
'Python'.isupper()
# Out:
# False

# %%
'Data Science'.istitle()
# Out:
# True

# %%
'hello 123'.isalpha()
# Out:
# False

# %%
'123.456'.isdigit()
# Out:
# False

# %%
'123.456'.isalnum()
# Out:
# False

# %%
'my cats'.isidentifier()
# Out:
# False

# %%
'd '.isspace()
# Out:
# False

# %%
'flag'.startswith('f')
# Out:
# True

# %%
'corporation'.endswith('n')
# Out:
# True

# %%
# ch3_5.py, 檢查是否為有效的郵件地址
email = input('請輸入電子郵件地址：')
email = email.lower()  # 將字串轉換為小寫

# 檢查是否包含 '@' 且以 '.com' 結尾，並輸出True或False
print('@' in email and email.endswith('.com'))
# Out:
# True

# %% [markdown]
# ##### 3.4.3 字串搜尋函數

# %%
s1 = 'learing by doing'

# %%
s1.count('ing')
# Out:
# 2

# %%
s1.find('ing')
# Out:
# 4

# %%
s1.rfind('ing')
# Out:
# 13

# %%
s1.find('w')
# Out:
# -1

# %% [markdown]
# ##### 3.4.4 字串編修與對齊函數

# %%
'kitty'.replace('y','en')
# Out:
# 'kitten'

# %%
' python '.strip()
# Out:
# 'python'

# %%
'www.buffalo.edu'.lstrip('@wi.')
# Out:
# 'buffalo.edu'

# %%
'www.buffalo.edu'.strip('.deuw')
# Out:
# 'buffalo'

# %%
'Jeanne'.ljust(8)
# Out:
# 'Jeanne  '

# %%
'Teresa'.center(8)
# Out:
# ' Teresa '

# %%
'2025'.zfill(8)
# Out:
# '00002025'

# %%
from wcwidth import wcswidth
wcswidth('蘋果(Apple)')
# Out:
# 11

# %%
# ch3_6.py, 使用wcswidth() 對齊文字
from wcwidth import wcswidth     # 載入wcswidth函數
 
print('使用ljust() 對齊文字:')
print('蘋果(Apple)'.ljust(14) + '20元')
print('奇異果(Kiwi)'.ljust(14) + '40元')
print('梅(Plum)'.ljust(14) + '50元')

print('使用 wcswidth() 對齊文字:')
print('蘋果(Apple)' + ' '*(14-wcswidth('蘋果(Apple)')) + '20元')
print('奇異果(Kiwi)' + ' '*(14-wcswidth('奇異果(Kiwi)')) + '40元')
print('梅(Plum)' + ' '*(14-wcswidth('梅(Plum)')) + '50元')
# Out:
# 使用ljust() 對齊文字:
# 蘋果(Apple)     20元
# 奇異果(Kiwi)     40元
# 梅(Plum)       50元
# 使用 wcswidth() 對齊文字:
# 蘋果(Apple)   20元
# 奇異果(Kiwi)  40元
# 梅(Plum)      50元

# %% [markdown]
# #### 3.5 串列與相關的處理函數

# %% [markdown]
# ##### 3.5.1 串列的建立與基本運算

# %%
[5, 8, 4]
# Out:
# [5, 8, 4]

# %%
[1,'s','tea',[9, 8, 7]]
# Out:
# [1, 's', 'tea', [9, 8, 7]]

# %%
[]
# Out:
# []

# %%
list('Python')
# Out:
# ['P', 'y', 't', 'h', 'o', 'n']

# %%
sorted([7, 9, 1], reverse=True)
# Out:
# [9, 7, 1]

# %%
sorted(['cat','kitty','kitten'])
# Out:
# ['cat', 'kitten', 'kitty']

# %%
any([0, 0, 3])
# Out:
# True

# %%
all([True, True, False])
# Out:
# False

# %%
'+'.join(['100','200'])
# Out:
# '100+200'

# %%
''.join(['a','p','p','l','e'])
# Out:
# 'apple'

# %%
'Python is fun'.split()
# Out:
# ['Python', 'is', 'fun']

# %%
'apple,banana'.split(',')
# Out:
# ['apple', 'banana']

# %%
# ch3_7.py, 處理手機號碼的分割、隱藏與格式化
phone = input('輸入手機號碼(格式：0912-345-678)：')
parts = phone.split('-')  		# 使用 split() 分割字串
formatted = ''.join(parts) 	# 使用 join() 去除 '-'
masked = f'{parts[0]}-***-{parts[-1]}' # 隱藏中間的部分
masked_f = formatted[:4]+'***'+formatted[-3:]  # 另一種隱藏格式

# 輸出結果
print(f'去除 – 後的號碼：{formatted}')
print(f'隱藏中間部分並用 - 隔開： {masked}')
print(f'隱藏中間部分： {masked_f}')
# Out:
# 去除 – 後的號碼：0911006208
# 隱藏中間部分並用 - 隔開： 0911-***-208
# 隱藏中間部分： 0911***208

# %%
len([1,0,3,6,4])
# Out:
# 5

# %%
max([3.14, 2.71, 1.25])
# Out:
# 3.14

# %%
sum([1, 2, 3])
# Out:
# 6

# %%
[1, 2] + [3, 4, 5]
# Out:
# [1, 2, 3, 4, 5]

# %%
[0,1,2]*3
# Out:
# [0, 1, 2, 0, 1, 2, 0, 1, 2]

# %%
3 in [1,2,3,4,5]
# Out:
# True

# %%
[1,3] in [1,2,3,4,5]
# Out:
# False

# %%
'py' in ['python']
# Out:
# 6

# %%
'py' in ['learn', 'py']
# Out:
# True

# %% [markdown]
# ##### 3.5.2 串列元素的提取

# %%
data = [7, 9, 11, 8, 17]

# %%
data[0], data[-1]
# Out:
# (7, 17)

# %%
data[2:]
# Out:
# [11, 8, 17]

# %%
data[:4]
# Out:
# [7, 9, 11, 8]

# %%
data[:-2]
# Out:
# [7, 9, 11]

# %%
data[0:4:2]
# Out:
# [7, 11]

# %%
data[-2::-1]
# Out:
# [8, 11, 9, 7]

# %%
data[::-1]
# Out:
# [17, 8, 11, 9, 7]

# %%
data=[[1,3,7], [4,8], [9,3,0,4]]

# %%
data[1]
# Out:
# [4, 8]

# %%
data[1][0]
# Out:
# 4

# %%
data[2]
# Out:
# [9, 3, 0, 4]

# %%
data[2][1:]
# Out:
# [3, 0, 4]

# %% [markdown]
# ##### 3.5.3 range() 函數

# %%
a = range(0, 8)

# %%
a
# Out:
# range(0, 8)

# %%
a[-1]
# Out:
# 7

# %%
a[3:7]
# Out:
# range(3, 7)

# %%
list(a)
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]

# %%
3 in a
# Out:
# True

# %% [markdown]
# ##### 3.5.4 串列的處理函數

# %%
a = [1, 2]; a.append(3); a
# Out:
# [1, 2, 3]

# %%
a = [1, 2]; a.append([3]); a
# Out:
# [1, 2, [3]]

# %%
a = [1, 2]; a.extend([3]); a
# Out:
# [1, 2, 3]

# %%
a = [1,2]; a.insert(1,9); a
# Out:
# [1, 9, 2]

# %%
a = [6, 7]; p=a.pop(0); print(p, a)
# Out:
# 6 [7]

# %%
a = [6, 7]; p=a.pop(); print(p, a)
# Out:
# 7 [6]

# %%
a = [1,2,3,2]; a.remove(2); a
# Out:
# [1, 3, 2]

# %%
a = [1,2,3]; a.clear(); a
# Out:
# []

# %%
# ch3_8.py, 模擬「購物清單」的操作
lst = []  # 建立購物清單

lst.append('牛奶')			# 使用 append() 增加品項
lst.append('麵包')
print('目前清單:', lst)  

lst.insert(1, '雞蛋')			# 使用 insert() 插入品項
print('插入雞蛋後:', lst)  

lst.extend(['荔枝', '咖啡'])	# 使用 extend() 加入多個品項
print('加入多個品項後:', lst)  

lst.remove('麵包')			# 使用 remove() 移除品項
print('移除麵包後:', lst)  

item = lst.pop()				# 使用 pop() 取出最後一項
print('取出最後一項:', item)  
print('更新後的清單:', lst)  

lst.clear()					# 使用 clear() 清空清單
print('購物完成後:', lst)
# Out:
# 目前清單: ['牛奶', '麵包']
# 插入雞蛋後: ['牛奶', '雞蛋', '麵包']
# 加入多個品項後: ['牛奶', '雞蛋', '麵包', '荔枝', '咖啡']
# 移除麵包後: ['牛奶', '雞蛋', '荔枝', '咖啡']
# 取出最後一項: 咖啡
# 更新後的清單: ['牛奶', '雞蛋', '荔枝']
# 購物完成後: []
