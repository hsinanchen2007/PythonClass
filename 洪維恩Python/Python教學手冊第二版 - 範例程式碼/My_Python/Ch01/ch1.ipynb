# %% [markdown]
# ### 第一章 認識Python

# %% [markdown]
# #### 1.1 Python 簡介

# %% [markdown]
# #### 1.2 下載與安裝 Python

# %% [markdown]
# #### 1.3 安裝與設定 VS Code

# %% [markdown]
# ##### 1.3.1 下載與安裝 VS Code

# %% [markdown]
# ##### 1.3.2 設定 VS Code 中文套件

# %% [markdown]
# ##### 1.3.3 安裝 Python 擴充套件

# %%
# ch1_1.py, 第一個Python程式
print(3+6)
print('Hello Python')
# Out:
# 9
# Hello Python

# %% [markdown]
# ##### 1.3.4 設定 VS Code 的環境

# %% [markdown]
# #### 1.4 使用 VS Code 執行 Python 程式

# %%
# # ch1_2.py, 於編輯視窗中執行的程式
a = 10  
b = 20 
print('a=',a)               		# 印出a的值
print('b=',b)               		# 印出b的值
print('Hello Python!')          	# 印出字串
# Out:
# a= 10
# b= 20
# Hello Python!

# %%
a=10

# %%
print(a)
# Out:
# 10

# %% [markdown]
# #### 1.5 開始進入 Python 的世界

# %% [markdown]
# ##### 1.5.1 Python 程式的基本認識

# %%
# ch1_3.py, 簡單的範例
a = 10
b = a + 5
print('b =', b)
# Out:
# b = 15

# %%
7 + 5
# Out:
# 12

# %%
a = 200

# %%
print(a)
# Out:
# 200

# %%
2cats = 0
# Out:
#   Cell In[11], line 1
#     2cats = 0
#     ^
# SyntaxError: invalid decimal literal

# %%
two_cats = 0

# %%
twoCats = 0

# %% [markdown]
# ##### 1.5.2 程式撰寫時的注意事項

# %%
1 + 2 + 3 + 4 + 5 + 6 + \
7 + 8 + 9
# Out:
# 45

# %%
a = 1; b = a + 2; print(b)
# Out:
# 3

# %%
print((3+5)*4)
# Out:
# 32

# %%
print((3 + 5) * 4)
# Out:
# 32

# %% [markdown]
# ##### 1.5.3 程式發生錯誤

# %%
Print('Hello Python')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 Print('Hello Python')
#
# NameError: name 'Print' is not defined

# %%
for = 12
# Out:
#   Cell In[16], line 1
#     for = 12
#         ^
# SyntaxError: invalid syntax

# %%
# ch1_4.py, 語意錯誤
price = 100
discount = 20
final_price = price + discount  # 應該是減去折扣，但這裡錯用了加法
print('折扣後價格=', final_price)
# Out:
# 折扣後價格= 120

# %% [markdown]
# ##### 1.5.4 程式的註解

# %%
# ch1_5.py, Python的註解
# This is a python comment
num = 4
print('num =', num)    # 印出num的值 (Python的註解)
# Out:
# num = 4

# %%
# ch1_6.py, 註解的範例
'''
A multiple line comment
Date: Feb. 14, 2025
Author: Junnie
'''
print('A simple Python program')
# Out:
# A simple Python program

# %% [markdown]
# #### 1.6 使用內建的 AI 功能 ─ Copilot
