# %% [markdown]
# ### 第二章 資料型別、變數與運算子

# %% [markdown]
# #### 2.1 簡單的資料型別

# %% [markdown]
# ##### 2.1.1 數值型別

# %%
type(6)

# %%
6+20
# Out:
# 26

# %%
1024**8
# Out:
# 1208925819614629174706176

# %%
0b1100
# Out:
# 12

# %%
0o16
# Out:
# 14

# %%
0x8a
# Out:
# 138

# %%
type(0b1001)
# Out:
# int

# %%
type(3.14)
# Out:
# float

# %%
type(5.)
# Out:
# float

# %%
3.2 + 4
# Out:
# 7.2

# %%
2.34e5
# Out:
# 234000.0

# %%
6.78e-3
# Out:
# 0.00678

# %%
2.56e-400
# Out:
# 0.0

# %%
3.14e310
# Out:
# inf

# %%
6j
# Out:
# 6j

# %%
2+1j
# Out:
# (2+1j)

# %%
z=5+3j

# %%
z.real
# Out:
# 5.0

# %%
1.5 > 4
# Out:
# False

# %%
type(True)
# Out:
# bool

# %%
True + 1
# Out:
# 2

# %%
False + True
# Out:
# 1

# %% [markdown]
# ##### 2.1.2 字串型別

# %%
'a string'
# Out:
# 'a string'

# %%
print('a string')
# Out:
# a string

# %%
"another string"
# Out:
# 'another string'

# %%
'''A
multiple line string'''
# Out:
# 'A\nmultiple line string'

# %% [markdown]
# #### 2.2 變數與常數

# %%
a = 12

# %%
type(a)
# Out:
# int

# %%
a = 3.14

# %%
type(a)
# Out:
# float

# %%
a = b = c = 12

# %%
print(a, b, c)
# Out:
# 12 12 12

# %%
a, b, c = 10, 3.14, 'Python'

# %%
print(a, b, c)
# Out:
# 10 3.14 Python

# %%
PI = 3.14159

# %%
MAX_SIZE = 256

# %%
True + 2
# Out:
# 3

# %%
True = 10
# Out:
#   Cell In[28], line 1
#     True = 10
#     ^
# SyntaxError: cannot assign to True

# %% [markdown]
# #### 2.3 常用的運算子

# %% [markdown]
# ##### 2.3.1 算術運算子

# %%
+50
# Out:
# 50

# %%
-100
# Out:
# -100

# %%
60 / 4
# Out:
# 15.0

# %%
20 // 3
# Out:
# 6

# %%
20 % 3
# Out:
# 2

# %%
2 ** 10
# Out:
# 1024

# %%
2 ** 0.5
# Out:
# 1.4142135623730951

# %% [markdown]
# ##### 2.3.2 比較運算子

# %%
7 >= 12
# Out:
# False

# %%
12 == 12.0
# Out:
# True

# %%
'Cats' < 'cat'
# Out:
# True

# %%
print(ord('C'), ord('c'))
# Out:
# 67 99

# %% [markdown]
# ##### 2.3.3 邏輯運算子

# %%
5<3 and 6<10
# Out:
# False

# %%
4<7 and 8<7 and 3>0
# Out:
# False

# %%
4<5 or 9>12
# Out:
# True

# %%
'a'=='a' or 7==2 and 8<5
# Out:
# True

# %%
not 8 < 10
# Out:
# False

# %%
bool('cat')
# Out:
# True

# %%
bool()
# Out:
# False

# %%
bool(3.14)
# Out:
# True

# %%
bool('')
# Out:
# False

# %%
# ch2_1.py, 運算子使用範例
a = 2 ** 3		# 次方運算，2 的 3 次方
b = 20 % 7		# 取餘數，20 除以 7 的餘數

# 比較運算子
is_equal = (a == b)	# 判斷是否相等
is_greater = (a > b)	# 判斷是否大於

# 邏輯運算子
result = is_equal or is_greater		# 邏輯 or 運算

# 輸出結果
print('a:', a, 'b:', b)
print('比較結果:', is_equal, is_greater)
print('邏輯結果:', result)
# Out:
# a: 8 b: 6
# 比較結果: False True
# 邏輯結果: True

# %% [markdown]
# #### 2.4 變數的設值與運算的優先順序

# %% [markdown]
# ##### 2.4.1 變數的設值

# %%
a = 12

# %%
a += 1; print(a)
# Out:
# 13

# %% [markdown]
# ##### 2.4.2 運算的優先順序

# %%
6 + 2 ** 3 * 4
# Out:
# 38

# %%
a = 2 + 1; a
# Out:
# 3

# %%
a=3; a += a**2 + 4; print(a)
# Out:
# 16

# %%
a=3
temp = a**2 + 4		# 運算後temp的值為13
a += temp			# 相當於 a = a + temp, 因此a的值變成16
print(a)
# Out:
# 16

# %%
# ch2_2.py, 複合設值和運算子優先順序範例
a = 10
b = 5

# 複合設值運算
a += 3      				# 相當於 a = a + 3
b *= 2      				# 相當於 b = b * 2
print('a:', a, 'b:', b)

# 運算子優先順序
result = a + b * 2   		# 先乘法後加法，相當於 a + (b * 2)
print('result:', result)

# 括號改變優先順序
result2 = (a + b) * 2  	# 先加法後乘法
print('result2:', result2)
# Out:
# a: 13 b: 10
# result: 33
# result2: 46

# %% [markdown]
# #### 2.5 型別轉換

# %% [markdown]
# ##### 2.5.1 隱式轉換

# %%
5 + 4.2
# Out:
# 9.2

# %%
19 + True
# Out:
# 20

# %%
10 / 4
# Out:
# 2.5

# %% [markdown]
# ##### 2.5.2 顯式轉換

# %%
int('2020') + 4
# Out:
# 2024

# %%
float(100)
# Out:
# 100.0

# %%
float('6.28')
# Out:
# 6.28

# %%
eval('6.28+12.4')
# Out:
# 18.68

# %%
# ch2_3.py, 隱式轉換與顯式轉換      
# 隱式轉換
a = 5      		# 整數
b = 2.5    		# 浮點數
result = a + b  	# 隱式轉換：整數 a 轉為浮點數
print('隱式轉換結果:', result, ', 型別:', type(result))
# 顯式轉換
c = '10'   		# 字串
d = int(c) 		# 顯式轉換：將字串轉為整數
print('顯式轉換結果:', d, ', 型別:', type(d))
print('轉換後 c 的型別:', type(c))    	# c型別不會被改變
# Out:
# 隱式轉換結果: 7.5 , 型別: <class 'float'>
# 顯式轉換結果: 10 , 型別: <class 'int'>
# 轉換後 c 的型別: <class 'str'>

# %% [markdown]
# #### 2.6 不同進位整數的轉換

# %%
int('0b11000011', 2)
# Out:
# 195

# %%
bin(16)
# Out:
# '0b10000'

# %%
int('0xef10', 16)
# Out:
# 61200

# %%
hex(61200)
# Out:
# '0xef10'

# %% [markdown]
# #### 2.7 輸出與輸入函數

# %% [markdown]
# ##### 2.7.1 Python 的輸出函數- print()

# %%
print('a=', 30)
# Out:
# a= 30

# %%
print(10, 20, 30, sep='+')
# Out:
# 10+20+30

# %%
print(10,20,30,sep='*',end='@\n')
# Out:
# 10*20*30@

# %%
print(12); print(14)
# Out:
# 12
# 14

# %%
print(12, end='#'); print(14)
# Out:
# 12#14

# %%
print(12, end=''); print(5)
# Out:
# 125

# %%
print('Hello \'Python\'')
# Out:
# Hello 'Python'

# %%
print("Hello 'Python'")
# Out:
# Hello 'Python'

# %%
print('It is a \nsunny day')
# Out:
# It is a
# sunny day

# %% [markdown]
# ##### 2.7.2 格式化字串

# %%
item, price = '可樂', 32.54

# %%
print(f'售價:{item:>4s},{price:6.1f}元')
# Out:
# 售價:  可樂,  32.5元

# %%
i,f,s = 12000,3.14,'Python'

# %%
f'i={i}, f={f}, s={s}'
# Out:
# 'i=12000, f=3.14, s=Python'

# %%
f'i={i:+,}, f={f:5.2f}'
# Out:
# 'i=+12,000, f= 3.14'

# %%
print(f'i={i:#x}, s={s:>08}')
# Out:
# i=0x2ee0, s=00Python

# %%
print(f'float={f*2:5.2f}')
# Out:
# float= 6.28

# %%
print(f'Add:{{4+5:^3d}}')
# Out:
# Add:{4+5:^3d}

# %%
print(f'Add:{{{4+5:^3d}}}')
# Out:
# Add:{ 9 }

# %%
s1='Hello'; s2='World'

# %%
print(f'\'{s1}\'+\'{s2}\'')
# Out:
# 'Hello'+'World'

# %%
# ch2_4.py, 使用 f-字串格式化輸出的範例
name = 'Bob'
age = 30
height = 175.5
score = 88.456

# 使用 f-string 進行格式化輸出
print(f'Name: {name}')				# 插入字串變數
print(f'Age: {age} years old')			# 插入整數變數
print(f'Height: {height:.1f} cm')		# 浮點數保留 1 位小數
print(f'Score: {score:.2f}')			# 浮點數保留 2 位小數
print(f'Summary: {name} is {age} years old.')	 # 插入多個變數
print(f'{name} is {height:.1f} cm tall.')		 # 格式化身高
print(f'{name}\'s score is {score:.1f} points.')	 # 格式化分數
# Out:
# Name: Bob
# Age: 30 years old
# Height: 175.5 cm
# Score: 88.46
# Summary: Bob is 30 years old.
# Bob is 175.5 cm tall.
# Bob's score is 88.5 points.

# %% [markdown]
# ##### 2.7.3 輸入函數- input()

# %%
# ch2_5.py, input() 函數的使用範例
name = input('Enter name: ')  			 # 輸入姓名
age = int(input('Enter age: '))		 # 輸入年齡並轉換為整數
height = float(input('Enter height: '))	 # 輸入身高並轉換為浮點數

print(f'Name: {name}')
print(f'Age: {age} years old')
print(f'Height: {height:.2f} cm')
# Out:
# Name: Alice
# Age: 25 years old
# Height: 168.50 cm

# %% [markdown]
# #### 2.8 關於浮點數計算時的誤差

# %%
0.1 + 0.2
# Out:
# 0.30000000000000004

# %%
0.3 - 0.2
# Out:
# 0.09999999999999998

# %%
0.3 * 3
# Out:
# 0.8999999999999999

# %%
0.5 + 0.9
# Out:
# 1.4

# %%
0.2 + 0.3
# Out:
# 0.5
